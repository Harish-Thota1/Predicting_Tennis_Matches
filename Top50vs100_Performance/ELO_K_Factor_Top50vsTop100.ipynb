# %%
# Importing Jupyter notebooks as modules
import import_ipynb

# Library for numerical computations with support for large arrays and matrices
import numpy as np

# Library for data manipulation and analysis
import pandas as pd

# Library for visualizations
import matplotlib.pyplot as plt

# Custom module for tennis-related analysis functions
import Tennis_Analysis_Tools as tennis_tools
# Out:
# importing Jupyter notebook from Tennis_Analysis_Tools.ipynb

# %%
def preprocess_dataset(betting_data_dfs):
    
    """
    Preprocess the betting dataset to prepare it for analysis.

    This function filters the dataset to include only completed matches,
    replaces 'NR' (Not Ranked) with NaN in ranking columns, converts rankings
    to numeric values, fills NaN values with 100000 (representing unranked players),
    creates a column indicating if the higher-ranked player won, and keeps only
    the essential columns for analysis.

    """
    
    # Filter the dataset to include only completed matches
    betting_data_dfs = betting_data_dfs[betting_data_dfs['Comment'].isin(['Completed'])]

    # Reset the index to ensure it's sequential after filtering
    betting_data_dfs.reset_index(drop=True, inplace=True)

    # Convert 'WRank' and 'LRank' columns to numeric, forcing errors to NaN
    betting_data_dfs['WRank'] = pd.to_numeric(betting_data_dfs['WRank'], errors='coerce')
    betting_data_dfs['LRank'] = pd.to_numeric(betting_data_dfs['LRank'], errors='coerce')

    # Fill NaN values in 'WRank' and 'LRank' with 100000 and convert to float
    betting_data_dfs['WRank'] = betting_data_dfs['WRank'].fillna(100000).astype(float)
    betting_data_dfs['LRank'] = betting_data_dfs['LRank'].fillna(100000).astype(float)

    # Create a column indicating if the higher-ranked player won (1 if true, 0 if false)
    betting_data_dfs['higher_rank_won'] = (betting_data_dfs['WRank'] < betting_data_dfs['LRank']).astype(int)

    # Define the essential columns to keep in the dataframe
    essential_columns = ['Date', 'Tournament', 'WRank', 'LRank', 'higher_rank_won', 'Winner', 'Loser']

    # Filter the dataframe to keep only the essential columns
    betting_data_filtered = betting_data_dfs[essential_columns]
    
    # Calculate the mean of numeric columns and fill NaN values with these means
    means = betting_data_filtered.select_dtypes(include=[np.number]).mean()
    betting_data_filtered.fillna(means, inplace=True)

    # Return the preprocessed dataframe
    return betting_data_filtered

# %%
def update_elo(winner_elo, loser_elo, K):
    # Calculate expected score for the winner
    expected_winner = 1 / (1 + 10 ** ((loser_elo - winner_elo) / 400))
    
    # Calculate the change in Elo ratings for the winner
    elo_change_winner = K * (1 - expected_winner)
    
    # Calculate the change in Elo ratings for the loser
    elo_change_loser = K * (expected_winner - 1)

    # Update the Elo ratings by adding the change to the original ratings
    updated_winner_elo = winner_elo + elo_change_winner
    updated_loser_elo = loser_elo + elo_change_loser

    # Return the updated Elo ratings and the expected score for the winner
    return (updated_winner_elo, updated_loser_elo, expected_winner)

# %%
def calculate_elo_with_k_top_players(betting_data_dfs_preprocessed, k):
    # Get unique player IDs from both 'Winner' and 'Loser' columns
    players_ids = pd.concat([betting_data_dfs_preprocessed['Winner'], betting_data_dfs_preprocessed['Loser']]).unique()
    # Initialize each player's ELO score to 1500
    elo_scores_constant_k = {player: 1500 for player in players_ids}

    # Iterate through each match in the preprocessed data
    for i in range(len(betting_data_dfs_preprocessed)):
        tennis_match_row = betting_data_dfs_preprocessed.iloc[i]
        winner_id = tennis_match_row['Winner']
        loser_id = tennis_match_row['Loser']

        # Retrieve the ELO scores before the match
        winner_elo_before, loser_elo_before = elo_scores_constant_k[winner_id], elo_scores_constant_k[loser_id]

        # Calculate the new ELO scores after the match
        winner_elo_after, loser_elo_after, prob_winner = update_elo(
            winner_elo_before, loser_elo_before, k)

        # Update the ELO scores in the dictionary
        elo_scores_constant_k[winner_id], elo_scores_constant_k[loser_id] = winner_elo_after, loser_elo_after

        # Store ELO scores and the computed probability of the winner winning before the match in the DataFrame
        betting_data_dfs_preprocessed.at[i, 'winner_elo_before'] = winner_elo_before
        betting_data_dfs_preprocessed.at[i, 'winner_elo_after'] = winner_elo_after
        betting_data_dfs_preprocessed.at[i, 'loser_elo_before'] = loser_elo_before
        betting_data_dfs_preprocessed.at[i, 'loser_elo_after'] = loser_elo_after

        # Compute the probability of the winner winning based on ELO differential
        prob_winner = 1 / (1 + 10 ** ((loser_elo_before - winner_elo_before) / 400))
        betting_data_dfs_preprocessed.at[i, 'prob_winner'] = prob_winner

        # Update the DataFrame with the match outcome and probability that the higher-ranked player won
        if tennis_match_row['higher_rank_won'] == 1:
            betting_data_dfs_preprocessed.at[i, 'match_outcome'] = int(betting_data_dfs_preprocessed.at[i, 'prob_winner'] > 0.5)  # Convert boolean to int
            betting_data_dfs_preprocessed.at[i, 'prob_high_ranked'] = betting_data_dfs_preprocessed.at[i, 'prob_winner']
        else:
            betting_data_dfs_preprocessed.at[i, 'match_outcome'] = int((1 - betting_data_dfs_preprocessed.at[i, 'prob_winner']) > 0.5)  # Convert boolean to int
            betting_data_dfs_preprocessed.at[i, 'prob_high_ranked'] = 1 - betting_data_dfs_preprocessed.at[i, 'prob_winner']

# %%
# Initialize a dictionary to store dataframes for each year
betting_data_dfs = {}

# %%
# Loop through each year from 2005 to 2019
for current_year in range(2005, 2020): 
    # Determine the file extension based on the year
    file_extension = 'xls' if current_year < 2013 else 'xlsx'
    
    # Construct the file path using the determined file extension
    file_path = f"/Users/harishthota/Desktop/UOA Project/Betting_Odds_Tennis/{current_year}.{file_extension}"
    
    # Read the Excel file and store it in the dictionary with the year as the key
    betting_data_dfs[current_year] = pd.read_excel(file_path)

# %%
betting_data_dfs[2019]
# Out:
#       ATP  Location              Tournament       Date       Series    Court  \
# 0       1  Brisbane  Brisbane International 2018-12-31       ATP250  Outdoor
# 1       1  Brisbane  Brisbane International 2018-12-31       ATP250  Outdoor
# 2       1  Brisbane  Brisbane International 2018-12-31       ATP250  Outdoor
# 3       1  Brisbane  Brisbane International 2018-12-31       ATP250  Outdoor
# 4       1  Brisbane  Brisbane International 2018-12-31       ATP250  Outdoor
# ...   ...       ...                     ...        ...          ...      ...
# 2605   66    London             Masters Cup 2019-11-15  Masters Cup   Indoor
# 2606   66    London             Masters Cup 2019-11-15  Masters Cup   Indoor
# 2607   66    London             Masters Cup 2019-11-16  Masters Cup   Indoor
# 2608   66    London             Masters Cup 2019-11-16  Masters Cup   Indoor
# 2609   66    London             Masters Cup 2019-11-17  Masters Cup   Indoor
#
# ...

# %%
# Combine DataFrames from all years into a single DataFrame, reindexing rows.
betting_data_dfs = pd.concat(betting_data_dfs.values(), ignore_index = True)

# %%
# Display a summary of the DataFrame to understand its structure and data types
betting_data_dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40390 entries, 0 to 40389
# Data columns (total 48 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ATP         40390 non-null  int64
#  1   Location    40390 non-null  object
#  2   Tournament  40390 non-null  object
#  3   Date        40390 non-null  datetime64[ns]
#  4   Series      40390 non-null  object
#  5   Court       40390 non-null  object
#  6   Surface     40390 non-null  object
#  7   Round       40390 non-null  object
#  8   Best of     40390 non-null  int64
#  9   Winner      40390 non-null  object
#  10  Loser       40390 non-null  object
#  11  WRank       40375 non-null  float64
#  12  LRank       40303 non-null  float64
#  13  WPts        38701 non-null  float64
#  14  LPts        38631 non-null  float64
#  15  W1          40155 non-null  float64
#  16  L1          40157 non-null  float64
#  17  W2          39765 non-null  object
# ...

# %%
# Generate descriptive statistics for numerical columns in the DataFrame
betting_data_dfs.describe()
# Out:
#                 ATP       Best of         WRank         LRank          WPts  \
# count  40390.000000  40390.000000  40375.000000  40303.000000  38701.000000
# mean      32.974944      3.378311     57.801536     90.384860   1828.537195
# std       18.006138      0.783274     72.735132    115.423997   2278.996487
# min        1.000000      3.000000      1.000000      1.000000      1.000000
# 25%       19.000000      3.000000     16.000000     34.000000    645.000000
# 50%       33.000000      3.000000     40.000000     64.000000   1010.000000
# 75%       49.000000      3.000000     75.000000    102.000000   1890.000000
# max       67.000000      5.000000   1890.000000   2159.000000  16950.000000
#
#                LPts            W1            L1           W4           L4  \
# count  38631.000000  40155.000000  40157.000000  3647.000000  3647.000000
# mean    1054.728379      5.801992      4.075155     5.783384     3.865643
# ...

# %%
# Retrieve and display the column names of the DataFrame
betting_data_dfs.columns
# Out:
# Index(['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface',
#        'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts',
#        'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets',
#        'Lsets', 'Comment', 'B365W', 'B365L', 'CBW', 'CBL', 'EXW', 'EXL', 'IWW',
#        'IWL', 'PSW', 'PSL', 'UBW', 'UBL', 'LBW', 'LBL', 'SJW', 'SJL', 'MaxW',
#        'MaxL', 'AvgW', 'AvgL'],
#       dtype='object')

# %%
betting_data_dfs_preprocessed = preprocess_dataset(betting_data_dfs)

# %%
betting_data_dfs_preprocessed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38847 entries, 0 to 38846
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             38847 non-null  datetime64[ns]
#  1   Tournament       38847 non-null  object
#  2   WRank            38847 non-null  float64
#  3   LRank            38847 non-null  float64
#  4   higher_rank_won  38847 non-null  int64
#  5   Winner           38847 non-null  object
#  6   Loser            38847 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 2.1+ MB

# %%
top_50_players = tennis_tools.precompute_top_players(betting_data_dfs_preprocessed, 50)
top_100_players = tennis_tools.precompute_top_players(betting_data_dfs_preprocessed, 100)

# %%
# Initialize lists to store results for different K values for top 50 and top 100 players
top50_results, top100_results = [], []

# Loop through K values from 0.1 to 1.0 in steps of 0.1 to compute Elo ratings and evaluate model performance
for k in np.arange(0.001, 1, 0.001):  # np.arange includes the start point but excludes the end point; adjust as necessary
    # Calculate Elo scores using the current K value for each match in the dataset
    
    elo_scores_constant_k = {}
    
    calculate_elo_with_k_top_players(betting_data_dfs_preprocessed, k)

    # Filter the data for validation based on date, considering matches after December 31, 2018
    betting_data_df_validation_preprocessed = betting_data_dfs_preprocessed[betting_data_dfs_preprocessed.Date > '2018-12-31']

    # Determine matches involving top 50 players of 2019 for both winner and loser
    betting_data_df_validation_preprocessed['Top50'] = betting_data_df_validation_preprocessed.apply(
        lambda row: row['Winner'] in top_50_players[2019] and row['Loser'] in top_50_players[2019], axis=1)
    # Determine matches involving top 100 players of 2019 for both winner and loser
    betting_data_df_validation_preprocessed['Top100'] = betting_data_df_validation_preprocessed.apply(
        lambda row: row['Winner'] in top_100_players[2019] and row['Loser'] in top_100_players[2019], axis=1)

    # Filter the validation data to include only matches between top 50 players
    betting_data_df_validation_top_50 = betting_data_df_validation_preprocessed[betting_data_df_validation_preprocessed['Top50'] == True]
    # Filter the validation data to include only matches between top 100 players
    betting_data_df_validation_top_100 = betting_data_df_validation_preprocessed[betting_data_df_validation_preprocessed['Top100'] == True]

    # Evaluate predictions for top 50 players and compute accuracy, calibration, and log loss
    accuracy_top50, calibration_top50, log_loss_top50 = tennis_tools.evaluate_predictions(
        betting_data_df_validation_top_50["higher_rank_won"],
        betting_data_df_validation_top_50["match_outcome"], 
        betting_data_df_validation_top_50['prob_high_ranked']
    )

    # Evaluate predictions for top 100 players and compute accuracy, calibration, and log loss
    accuracy_top100, calibration_top100, log_loss_top100 = tennis_tools.evaluate_predictions(
        betting_data_df_validation_top_100["higher_rank_won"],
        betting_data_df_validation_top_100["match_outcome"], 
        betting_data_df_validation_top_100['prob_high_ranked']
    )

    # Store the results (K, accuracy, calibration, log loss) for top 50 players
    top50_results.append((k, accuracy_top50, calibration_top50, log_loss_top50))
    # Store the results (K, accuracy, calibration, log loss) for top 100 players
    top100_results.append((k, accuracy_top100, calibration_top100, log_loss_top100))

# %%
# Dictionary to associate descriptive names with datasets for results analysis
results = {
    "Top 50 Results": top50_results,
    "Top 100 Results": top100_results
}

# Iterate through each results dataset to analyze and plot performance metrics
for name, data in results.items():
    # Extracting K-values, accuracies, calibrations, and log losses from the results
    k_values = [result[0] for result in data]
    accuracies = [float(result[1]) for result in data]
    calibrations = [float(result[2]) for result in data]
    log_losses = [float(result[3]) for result in data]

    # Identify the index of the minimum log loss to find the optimal K-value
    index_of_min_log_loss = log_losses.index(min(log_losses))
    optimal_k_log_loss = k_values[index_of_min_log_loss]
    best_accuracy = accuracies[index_of_min_log_loss]
    best_calibration = calibrations[index_of_min_log_loss]
    best_log_loss = log_losses[index_of_min_log_loss]

    # Setting up the plot for visualization
    plt.figure(figsize=(14, 8))
    plt.plot(k_values, log_losses, label='Log Loss', color='blue', marker='o')
    plt.axvline(optimal_k_log_loss, color='red', linestyle='--', label=f'Optimal K = {optimal_k_log_loss}')

    # Adding labels, ticks, and legends to the plot for clarity
    plt.xlabel('K Value', fontsize=14, fontweight='bold')
    plt.ylabel('Log Loss', fontsize=14, fontweight='bold')
    plt.xticks(fontsize=12, fontweight='bold')
    plt.yticks(fontsize=12, fontweight='bold')
    plt.legend(fontsize=12, frameon=True, shadow=True)
    
    # Set the title dynamically based on the dataset being analyzed
    plt.title(f'Log Loss vs Constant K Value for {name}', fontsize=16, fontweight='bold')

    # Annotating the plot with optimal values for better insight
    annotation_text = f'Best Accuracy: {best_accuracy:.4f}\nBest Calibration: {best_calibration:.4f}\nBest Log Loss: {best_log_loss:.4f}'
    plt.annotate(annotation_text,
                 xy=(optimal_k_log_loss, best_log_loss),
                 xytext=(optimal_k_log_loss + 10, best_log_loss - 0.05),
                 textcoords="offset points",
                 bbox=dict(boxstyle="round,pad=0.3", edgecolor='black', facecolor='white', alpha=0.9),
                 arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.5", color='black'),
                 fontsize=12, fontweight='bold')

    # Adjust layout and display the plot
    plt.tight_layout()
    plt.show()
