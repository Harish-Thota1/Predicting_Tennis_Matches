# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
def accuracy(actual, predictions):
    logr_accuracy_all_predictors = np.mean(actual == predictions)
    return logr_accuracy_all_predictors  # Corrected indentation

def calibration(actual, predictions):
    return np.sum(predictions) / np.sum(actual)

def logloss(actual, predictions):
    epsilon = 1e-15
    predictions = np.clip(predictions, epsilon, 1 - epsilon)
    
    logr_logloss_all_predictors = -(1 / len(actual)) * np.sum(
        actual * np.log(predictions) + (1 - actual) * np.log(1 - predictions))
    return logr_logloss_all_predictors

# %%
def calculate_implied_probabilities(odds_w, odds_l):
    if odds_w == 0 or odds_l == 0 or pd.isna(odds_w) or pd.isna(odds_l):
        return 0, 0 
    implied_prob_w = 1 / odds_w
    implied_prob_l = 1 / odds_l
    overround = implied_prob_w + implied_prob_l
    normalized_prob_w = implied_prob_w / overround
    normalized_prob_l = implied_prob_l / overround
    return normalized_prob_w, normalized_prob_l

# %%
def evaluate_predictions(actual_outcomes, binary_predictions,  probability_predictions):
    
    accuracy_result = accuracy(actual_outcomes, binary_predictions)
    
    calibration_result = calibration(actual_outcomes, probability_predictions)
    
    logloss_result = logloss(actual_outcomes, probability_predictions)
    
    return {
        accuracy_result,
        calibration_result,
        logloss_result
    }

# %%
tennis_dfs = {}

# %%
for year in range(2000, 2020): 
    file_extension = 'xls' if year < 2013 else 'xlsx'
    file_path = f"Betting_Odds_Tennis/{year}.{file_extension}"
    tennis_dfs[year] = pd.read_excel(file_path)

# %%
tennis_dfs[2019]
# Out:
#       ATP  Location              Tournament       Date       Series    Court  \
# 0       1  Brisbane  Brisbane International 2018-12-31       ATP250  Outdoor
# 1       1  Brisbane  Brisbane International 2018-12-31       ATP250  Outdoor
# 2       1  Brisbane  Brisbane International 2018-12-31       ATP250  Outdoor
# 3       1  Brisbane  Brisbane International 2018-12-31       ATP250  Outdoor
# 4       1  Brisbane  Brisbane International 2018-12-31       ATP250  Outdoor
# ...   ...       ...                     ...        ...          ...      ...
# 2605   66    London             Masters Cup 2019-11-15  Masters Cup   Indoor
# 2606   66    London             Masters Cup 2019-11-15  Masters Cup   Indoor
# 2607   66    London             Masters Cup 2019-11-16  Masters Cup   Indoor
# 2608   66    London             Masters Cup 2019-11-16  Masters Cup   Indoor
# 2609   66    London             Masters Cup 2019-11-17  Masters Cup   Indoor
#
#      Surface        Round  Best of         Winner  ... Lsets    Comment  \
# 0       Hard    1st Round        3    Dimitrov G.  ...   0.0  Completed
# 1       Hard    1st Round        3      Raonic M.  ...   0.0  Completed
# 2       Hard    1st Round        3  Kecmanovic M.  ...   0.0  Completed
# 3       Hard    1st Round        3     Millman J.  ...   1.0  Completed
# 4       Hard    1st Round        3    Uchiyama Y.  ...   0.0  Completed
# ...      ...          ...      ...            ...  ...   ...        ...
# 2605    Hard  Round Robin        3      Nadal R.   ...   1.0  Completed
# 2606    Hard  Round Robin        3     Zverev A.   ...   0.0  Completed
# 2607    Hard   Semifinals        3  Tsitsipas S.   ...   0.0  Completed
# 2608    Hard   Semifinals        3      Thiem D.   ...   0.0  Completed
# 2609    Hard    The Final        3  Tsitsipas S.   ...   1.0  Completed
#
#       B365W  B365L   PSW   PSL  MaxW  MaxL  AvgW  AvgL
# 0      1.36   3.00  1.36  3.37  1.42  3.60  1.35  3.18
# 1      1.18   4.50  1.23  4.68  1.27  4.84  1.22  4.26
# 2      1.57   2.25  1.67  2.32  1.71  2.40  1.63  2.28
# 3      1.40   2.75  1.41  3.13  1.45  3.20  1.40  2.95
# 4      2.62   1.44  2.73  1.51  3.26  1.53  2.69  1.47
# ...     ...    ...   ...   ...   ...   ...   ...   ...
# 2605   1.44   2.75  1.39  3.26  1.48  3.30  1.41  2.93
# 2606   1.90   1.90  2.14  1.79  2.24  2.06  1.92  1.90
# 2607   3.50   1.30  3.75  1.33  3.75  1.40  3.39  1.33
# 2608   1.80   2.00  1.84  2.10  1.87  2.20  1.78  2.06
# 2609   2.00   1.80  2.00  1.93  2.05  1.93  1.96  1.86
#
# [2610 rows x 36 columns]

# %%
all_years_df = pd.concat(tennis_dfs.values(), ignore_index=True)

# %%
all_years_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54908 entries, 0 to 54907
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ATP         54908 non-null  int64
#  1   Location    54908 non-null  object
#  2   Tournament  54908 non-null  object
#  3   Date        54908 non-null  datetime64[ns]
#  4   Series      54908 non-null  object
#  5   Court       54908 non-null  object
#  6   Surface     54908 non-null  object
#  7   Round       54908 non-null  object
#  8   Best of     54908 non-null  int64
#  9   Winner      54908 non-null  object
#  10  Loser       54908 non-null  object
#  11  WRank       54889 non-null  object
#  12  LRank       54816 non-null  object
#  13  W1          54624 non-null  float64
#  14  L1          54626 non-null  float64
#  15  W2          54102 non-null  object
#  16  L2          54103 non-null  object
#  17  W3          25417 non-null  object
#  18  L3          25416 non-null  object
#  19  W4          4996 non-null   float64
#  20  L4          4996 non-null   float64
#  21  W5          1887 non-null   float64
#  22  L5          1887 non-null   float64
#  23  Wsets       54663 non-null  float64
#  24  Lsets       54662 non-null  float64
#  25  Comment     54908 non-null  object
#  26  CBW         17506 non-null  float64
#  27  CBL         17506 non-null  float64
#  28  GBW         5055 non-null   float64
#  29  GBL         5055 non-null   float64
#  30  IWW         13358 non-null  float64
#  31  IWL         13358 non-null  float64
#  32  SBW         5424 non-null   float64
#  33  SBL         5424 non-null   float64
#  34  B365W       46240 non-null  float64
#  35  B365L       46263 non-null  float64
#  36  B&WW        1097 non-null   float64
#  37  B&WL        1097 non-null   float64
#  38  EXW         39411 non-null  object
#  39  EXL         39416 non-null  float64
#  40  PSW         39938 non-null  float64
#  41  PSL         39938 non-null  float64
#  42  WPts        38701 non-null  float64
#  43  LPts        38631 non-null  float64
#  44  UBW         10671 non-null  float64
#  45  UBL         10671 non-null  float64
#  46  LBW         28131 non-null  float64
#  47  LBL         28142 non-null  float64
#  48  SJW         15572 non-null  float64
#  49  SJL         15579 non-null  float64
#  50  MaxW        25354 non-null  float64
#  51  MaxL        25354 non-null  float64
#  52  AvgW        25354 non-null  float64
#  53  AvgL        25354 non-null  float64
# dtypes: datetime64[ns](1), float64(35), int64(2), object(16)
# memory usage: 22.6+ MB

# %%
all_years_df.columns
# Out:
# Index(['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface',
#        'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'W1', 'L1',
#        'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets',
#        'Comment', 'CBW', 'CBL', 'GBW', 'GBL', 'IWW', 'IWL', 'SBW', 'SBL',
#        'B365W', 'B365L', 'B&WW', 'B&WL', 'EXW', 'EXL', 'PSW', 'PSL', 'WPts',
#        'LPts', 'UBW', 'UBL', 'LBW', 'LBL', 'SJW', 'SJL', 'MaxW', 'MaxL',
#        'AvgW', 'AvgL'],
#       dtype='object')

# %%
def preprocess_dataset(df):

    # Not considering Max and Avg columns

    odds_columns = ['B365W', 'B365L', 'B&WW', 'B&WL', 'CBW', 'CBL', 'EXW', 'EXL', 'LBW', 'LBL', 
                'GBW', 'GBL', 'IWW', 'IWL', 'PSW', 'PSL', 'SBW', 'SBL', 'SJW', 'SJL',
                'UBW', 'UBL']


    df['WRank'].replace('NR', np.nan, inplace=True)
    df['LRank'].replace('NR', np.nan, inplace=True)

    df['WRank'] = df['WRank'].fillna(100000).astype(float)
    df['LRank'] = df['LRank'].fillna(100000).astype(float)

    df['higher_rank_won'] = (df['WRank'] < df['LRank']).astype(int)
    df['higher_rank_points'] = df['higher_rank_won'] * df['WPts'] + df['LPts'] * (1 - df['higher_rank_won'])
    df['lower_rank_points'] = (1 - df['higher_rank_won']) * df['WPts'] + df['LPts'] * df['higher_rank_won']
    df['points_diff'] = df['higher_rank_points'] - df['lower_rank_points']

    essential_columns = ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'higher_rank_won', 'higher_rank_points', 'lower_rank_points', 'points_diff', 'WRank', 'LRank', 'Wsets', 'Lsets', 'Winner', 'Loser']

    df_odds = df[essential_columns + odds_columns]


    df_odds[odds_columns] = df_odds[odds_columns].apply(pd.to_numeric, errors='coerce')


    df_odds['EXW'] = df_odds['EXW'].replace('2.,3', 2.3).astype(float)


    df_odds = df_odds.astype({'Location': 'category', 'Tournament': 'category', 'Series': 'category','Court': 'category', 'Surface': 'category', 'Round': 'category' })



    categorical_features = ['Location', 'Tournament', 'Series', 'Court', 'Surface','Round']
    encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)  # Ensure output is a dense array

    encoded_features = encoder.fit_transform(df_odds[categorical_features])

    df_encoded = pd.DataFrame(encoded_features, columns=encoder.get_feature_names_out(categorical_features))

    df_odds.reset_index(drop=True, inplace=True)

    df_final = pd.concat([df_odds.drop(columns=categorical_features), df_encoded], axis=1)

    df_final.dropna(axis=1, how='all', inplace=True)

    return df_final

# %%
df_odds_preprocessed = preprocess_dataset(all_years_df)

# %%
df_odds_preprocessed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54908 entries, 0 to 54907
# Columns: 396 entries, ATP to Round_The Final
# dtypes: datetime64[ns](1), float64(390), int64(3), object(2)
# memory usage: 165.9+ MB

# %%
means = df_odds_preprocessed.select_dtypes(include=[np.number]).mean()
df_odds_preprocessed.fillna(means, inplace=True)

# %%
players_ids = pd.concat([df_odds_preprocessed['Winner'], df_odds_preprocessed['Loser']]).unique()
players_ids
# Out:
# array(['Dosedel S.', 'Enqvist T.', 'Escude N.', ..., 'Dubrivnyy A.',
#        'Kachmazov A.', 'Medvedev D. '], dtype=object)

# %%
atp_ranking_history = {player_id: [] for player_id in players_ids}
elo_scores_constant_k = {player: 1500 for player in players_ids}
elo_scores_varied_k = elo_scores_constant_k.copy()

# %%
def calculate_k(m_i, delta=100, nu=5, sigma=0.1):
    return delta / ((m_i + nu) ** sigma)

# %%
def update_elo(winner_elo, loser_elo, games_played_winner, games_played_loser, K, use_varied_k=False):
    if use_varied_k:
        K_winner = calculate_k(games_played_winner)
        K_loser = calculate_k(games_played_loser)
    else:
        K_winner = K_loser = K 

    expected_winner = 1 / (1 + 10 ** ((loser_elo - winner_elo) / 400))
    elo_change_winner = K_winner * (1 - expected_winner)
    elo_change_loser = K_loser * (expected_winner - 1)


    return (winner_elo, winner_elo + elo_change_winner, loser_elo, loser_elo + elo_change_loser, expected_winner)

# %%
games_played = {}

# %%
def calculate_elo_with_k(df_odds_preprocessed, k):
    players_ids = pd.concat([df_odds_preprocessed['Winner'], df_odds_preprocessed['Loser']]).unique()
    elo_scores = {player: 1500 for player in players_ids}
    games_played = {player: 0 for player in players_ids}


    for i in range(len(df_odds_preprocessed)):
        tennis_match_row = df_odds_preprocessed.iloc[i]
        winner_id = tennis_match_row['Winner']
        loser_id = tennis_match_row['Loser']
        higher_ranked_wins = tennis_match_row['higher_rank_won']

        games_played[winner_id] = games_played.get(winner_id, 0) + 1
        games_played[loser_id] = games_played.get(loser_id, 0) + 1

        winner_elo_before, loser_elo_before = elo_scores_constant_k[winner_id], elo_scores_constant_k[loser_id]


        _, winner_elo_after, _, loser_elo_after, prob_winner = update_elo(
            winner_elo_before, loser_elo_before, 
            games_played[winner_id], games_played[loser_id], k, use_varied_k=False)

        elo_scores_constant_k[winner_id], elo_scores_constant_k[loser_id] = winner_elo_after, loser_elo_after




        df_odds_preprocessed.at[i, 'winner_elo_before'] = winner_elo_before
        df_odds_preprocessed.at[i, 'winner_elo_after'] = winner_elo_after
        df_odds_preprocessed.at[i, 'loser_elo_before'] = loser_elo_before
        df_odds_preprocessed.at[i, 'loser_elo_after'] = loser_elo_after

        prob_winner = 1 / (1 + 10 ** ((loser_elo_before - winner_elo_before) / 400))
        df_odds_preprocessed.at[i, 'prob_winner'] = prob_winner

        if tennis_match_row['higher_rank_won'] == 1:
            df_odds_preprocessed.at[i, 'match_outcome'] = int(df_odds_preprocessed.at[i, 'prob_winner'] > 0.5)  # Convert boolean to int using int()
            df_odds_preprocessed.at[i, 'prob_high_ranked'] = df_odds_preprocessed.at[i, 'prob_winner']
        else:
            df_odds_preprocessed.at[i, 'match_outcome'] = int((1 - df_odds_preprocessed.at[i, 'prob_winner']) > 0.5)  # Convert boolean to int using int()
            df_odds_preprocessed.at[i, 'prob_high_ranked'] = 1 - df_odds_preprocessed.at[i, 'prob_winner']
            
    
    return df_odds_preprocessed

# %%
split_time = '2018-12-31'
df_odds_validation = df_odds_preprocessed[df_odds_preprocessed.Date > split_time]
df_odds_validation
results = []

# %%
for k in range(1,500):
    df_updated = calculate_elo_with_k(df_odds_preprocessed.copy(), k)
    df_validation = df_updated[df_updated.Date > '2018-12-31']
    df_validation["match_outcome"] = df_validation["match_outcome"].astype(int)

    accuracy1, calibration1, logloss1 = evaluate_predictions(df_validation["higher_rank_won"], 
                                                  df_validation["match_outcome"], 
                                                  df_validation['prob_high_ranked'])
    results.append((k, accuracy1, calibration1, logloss1))

# %%
optimal_k_logloss = min(results, key=lambda x: x[3])[0]
print(f"Optimal K based on Log Loss: {optimal_k_logloss}")
# Out:
# Optimal K based on Log Loss: 21

# %%
for result in results:
    print(f"K={result[0]}: Accuracy={result[1]:.4f}, Calibration={result[2]:.4f}, LogLoss={result[3]:.4f}")
# Out:
# K=1: Accuracy=0.6035, Calibration=0.8685, LogLoss=0.6599
# K=2: Accuracy=0.6155, Calibration=0.9149, LogLoss=0.6470
# K=3: Accuracy=0.6174, Calibration=0.9483, LogLoss=0.6407
# K=4: Accuracy=0.6278, Calibration=0.9724, LogLoss=0.6358
# K=5: Accuracy=0.6332, Calibration=0.9900, LogLoss=0.6316
# K=6: Accuracy=0.6410, Calibration=1.0030, LogLoss=0.6281
# K=7: Accuracy=0.6456, Calibration=1.0127, LogLoss=0.6253
# K=8: Accuracy=0.6464, Calibration=1.0202, LogLoss=0.6231
# K=9: Accuracy=0.6448, Calibration=1.0261, LogLoss=0.6214
# K=10: Accuracy=0.6467, Calibration=1.0308, LogLoss=0.6200
# K=11: Accuracy=0.6483, Calibration=1.0347, LogLoss=0.6190
# K=12: Accuracy=0.6437, Calibration=1.0379, LogLoss=0.6181
# K=13: Accuracy=0.6440, Calibration=1.0407, LogLoss=0.6174
# K=14: Accuracy=0.6452, Calibration=1.0430, LogLoss=0.6169
# K=15: Accuracy=0.6464, Calibration=1.0451, LogLoss=0.6164
# K=16: Accuracy=0.6471, Calibration=1.0469, LogLoss=0.6160
# K=17: Accuracy=0.6460, Calibration=1.0485, LogLoss=0.6158
# K=18: Accuracy=0.6456, Calibration=1.0499, LogLoss=0.6155
# K=19: Accuracy=0.6456, Calibration=1.0513, LogLoss=0.6154
# K=20: Accuracy=0.6487, Calibration=1.0525, LogLoss=0.6153
# K=21: Accuracy=0.6487, Calibration=1.0536, LogLoss=0.6153
# K=22: Accuracy=0.6510, Calibration=1.0546, LogLoss=0.6153
# K=23: Accuracy=0.6525, Calibration=1.0556, LogLoss=0.6154
# K=24: Accuracy=0.6529, Calibration=1.0565, LogLoss=0.6156
# K=25: Accuracy=0.6514, Calibration=1.0573, LogLoss=0.6157
# K=26: Accuracy=0.6502, Calibration=1.0581, LogLoss=0.6159
# K=27: Accuracy=0.6487, Calibration=1.0588, LogLoss=0.6162
# K=28: Accuracy=0.6479, Calibration=1.0595, LogLoss=0.6165
# K=29: Accuracy=0.6487, Calibration=1.0602, LogLoss=0.6168
# K=30: Accuracy=0.6510, Calibration=1.0608, LogLoss=0.6171
# K=31: Accuracy=0.6506, Calibration=1.0614, LogLoss=0.6174
# K=32: Accuracy=0.6514, Calibration=1.0619, LogLoss=0.6178
# K=33: Accuracy=0.6518, Calibration=1.0625, LogLoss=0.6182
# K=34: Accuracy=0.6545, Calibration=1.0629, LogLoss=0.6186
# K=35: Accuracy=0.6560, Calibration=1.0634, LogLoss=0.6191
# K=36: Accuracy=0.6552, Calibration=1.0638, LogLoss=0.6195
# K=37: Accuracy=0.6541, Calibration=1.0643, LogLoss=0.6200
# K=38: Accuracy=0.6541, Calibration=1.0647, LogLoss=0.6204
# K=39: Accuracy=0.6533, Calibration=1.0650, LogLoss=0.6209
# K=40: Accuracy=0.6541, Calibration=1.0654, LogLoss=0.6214
# K=41: Accuracy=0.6545, Calibration=1.0657, LogLoss=0.6220
# K=42: Accuracy=0.6533, Calibration=1.0660, LogLoss=0.6225
# K=43: Accuracy=0.6541, Calibration=1.0664, LogLoss=0.6230
# K=44: Accuracy=0.6525, Calibration=1.0666, LogLoss=0.6236
# K=45: Accuracy=0.6525, Calibration=1.0669, LogLoss=0.6241
# K=46: Accuracy=0.6525, Calibration=1.0672, LogLoss=0.6247
# K=47: Accuracy=0.6533, Calibration=1.0674, LogLoss=0.6253
# K=48: Accuracy=0.6533, Calibration=1.0677, LogLoss=0.6259
# K=49: Accuracy=0.6533, Calibration=1.0679, LogLoss=0.6265
# K=50: Accuracy=0.6541, Calibration=1.0681, LogLoss=0.6271
# K=51: Accuracy=0.6537, Calibration=1.0683, LogLoss=0.6277
# K=52: Accuracy=0.6529, Calibration=1.0685, LogLoss=0.6283
# K=53: Accuracy=0.6518, Calibration=1.0687, LogLoss=0.6289
# K=54: Accuracy=0.6498, Calibration=1.0689, LogLoss=0.6295
# K=55: Accuracy=0.6502, Calibration=1.0690, LogLoss=0.6302
# K=56: Accuracy=0.6506, Calibration=1.0692, LogLoss=0.6308
# K=57: Accuracy=0.6502, Calibration=1.0693, LogLoss=0.6315
# K=58: Accuracy=0.6521, Calibration=1.0695, LogLoss=0.6321
# K=59: Accuracy=0.6506, Calibration=1.0696, LogLoss=0.6328
# K=60: Accuracy=0.6510, Calibration=1.0698, LogLoss=0.6334
# K=61: Accuracy=0.6494, Calibration=1.0699, LogLoss=0.6341
# K=62: Accuracy=0.6471, Calibration=1.0700, LogLoss=0.6348
# K=63: Accuracy=0.6471, Calibration=1.0701, LogLoss=0.6354
# K=64: Accuracy=0.6479, Calibration=1.0702, LogLoss=0.6361
# K=65: Accuracy=0.6483, Calibration=1.0703, LogLoss=0.6368
# K=66: Accuracy=0.6479, Calibration=1.0704, LogLoss=0.6375
# K=67: Accuracy=0.6487, Calibration=1.0705, LogLoss=0.6382
# K=68: Accuracy=0.6479, Calibration=1.0706, LogLoss=0.6389
# K=69: Accuracy=0.6483, Calibration=1.0707, LogLoss=0.6396
# K=70: Accuracy=0.6491, Calibration=1.0708, LogLoss=0.6403
# K=71: Accuracy=0.6491, Calibration=1.0708, LogLoss=0.6410
# K=72: Accuracy=0.6471, Calibration=1.0709, LogLoss=0.6418
# K=73: Accuracy=0.6464, Calibration=1.0710, LogLoss=0.6425
# K=74: Accuracy=0.6448, Calibration=1.0710, LogLoss=0.6432
# K=75: Accuracy=0.6444, Calibration=1.0711, LogLoss=0.6439
# K=76: Accuracy=0.6429, Calibration=1.0711, LogLoss=0.6447
# K=77: Accuracy=0.6429, Calibration=1.0712, LogLoss=0.6454
# K=78: Accuracy=0.6433, Calibration=1.0712, LogLoss=0.6462
# K=79: Accuracy=0.6440, Calibration=1.0713, LogLoss=0.6469
# K=80: Accuracy=0.6440, Calibration=1.0713, LogLoss=0.6477
# K=81: Accuracy=0.6429, Calibration=1.0714, LogLoss=0.6484
# K=82: Accuracy=0.6425, Calibration=1.0714, LogLoss=0.6492
# K=83: Accuracy=0.6413, Calibration=1.0715, LogLoss=0.6499
# K=84: Accuracy=0.6421, Calibration=1.0715, LogLoss=0.6507
# K=85: Accuracy=0.6417, Calibration=1.0715, LogLoss=0.6515
# K=86: Accuracy=0.6410, Calibration=1.0716, LogLoss=0.6522
# K=87: Accuracy=0.6394, Calibration=1.0716, LogLoss=0.6530
# K=88: Accuracy=0.6394, Calibration=1.0716, LogLoss=0.6538
# K=89: Accuracy=0.6386, Calibration=1.0716, LogLoss=0.6546
# K=90: Accuracy=0.6394, Calibration=1.0717, LogLoss=0.6554
# K=91: Accuracy=0.6375, Calibration=1.0717, LogLoss=0.6562
# K=92: Accuracy=0.6375, Calibration=1.0717, LogLoss=0.6570
# K=93: Accuracy=0.6375, Calibration=1.0717, LogLoss=0.6578
# K=94: Accuracy=0.6375, Calibration=1.0717, LogLoss=0.6586
# K=95: Accuracy=0.6379, Calibration=1.0718, LogLoss=0.6594
# K=96: Accuracy=0.6379, Calibration=1.0718, LogLoss=0.6602
# K=97: Accuracy=0.6383, Calibration=1.0718, LogLoss=0.6610
# K=98: Accuracy=0.6386, Calibration=1.0718, LogLoss=0.6618
# K=99: Accuracy=0.6390, Calibration=1.0718, LogLoss=0.6626
# K=100: Accuracy=0.6386, Calibration=1.0718, LogLoss=0.6635
# K=101: Accuracy=0.6394, Calibration=1.0718, LogLoss=0.6643
# K=102: Accuracy=0.6390, Calibration=1.0718, LogLoss=0.6651
# K=103: Accuracy=0.6398, Calibration=1.0719, LogLoss=0.6659
# K=104: Accuracy=0.6402, Calibration=1.0719, LogLoss=0.6668
# K=105: Accuracy=0.6390, Calibration=1.0719, LogLoss=0.6676
# K=106: Accuracy=0.6386, Calibration=1.0719, LogLoss=0.6685
# K=107: Accuracy=0.6375, Calibration=1.0719, LogLoss=0.6693
# K=108: Accuracy=0.6379, Calibration=1.0719, LogLoss=0.6702
# K=109: Accuracy=0.6371, Calibration=1.0719, LogLoss=0.6710
# K=110: Accuracy=0.6371, Calibration=1.0719, LogLoss=0.6719
# K=111: Accuracy=0.6375, Calibration=1.0719, LogLoss=0.6727
# K=112: Accuracy=0.6375, Calibration=1.0719, LogLoss=0.6736
# K=113: Accuracy=0.6359, Calibration=1.0719, LogLoss=0.6745
# K=114: Accuracy=0.6359, Calibration=1.0719, LogLoss=0.6753
# K=115: Accuracy=0.6356, Calibration=1.0719, LogLoss=0.6762
# K=116: Accuracy=0.6344, Calibration=1.0719, LogLoss=0.6771
# K=117: Accuracy=0.6340, Calibration=1.0719, LogLoss=0.6780
# K=118: Accuracy=0.6332, Calibration=1.0719, LogLoss=0.6789
# K=119: Accuracy=0.6329, Calibration=1.0719, LogLoss=0.6797
# K=120: Accuracy=0.6317, Calibration=1.0719, LogLoss=0.6806
# K=121: Accuracy=0.6321, Calibration=1.0719, LogLoss=0.6815
# K=122: Accuracy=0.6321, Calibration=1.0719, LogLoss=0.6824
# K=123: Accuracy=0.6313, Calibration=1.0719, LogLoss=0.6833
# K=124: Accuracy=0.6313, Calibration=1.0719, LogLoss=0.6842
# K=125: Accuracy=0.6317, Calibration=1.0719, LogLoss=0.6851
# K=126: Accuracy=0.6302, Calibration=1.0719, LogLoss=0.6861
# K=127: Accuracy=0.6305, Calibration=1.0719, LogLoss=0.6870
# K=128: Accuracy=0.6313, Calibration=1.0718, LogLoss=0.6879
# K=129: Accuracy=0.6317, Calibration=1.0718, LogLoss=0.6888
# K=130: Accuracy=0.6309, Calibration=1.0718, LogLoss=0.6897
# K=131: Accuracy=0.6298, Calibration=1.0718, LogLoss=0.6907
# K=132: Accuracy=0.6282, Calibration=1.0718, LogLoss=0.6916
# K=133: Accuracy=0.6275, Calibration=1.0718, LogLoss=0.6925
# K=134: Accuracy=0.6263, Calibration=1.0718, LogLoss=0.6935
# K=135: Accuracy=0.6267, Calibration=1.0718, LogLoss=0.6944
# K=136: Accuracy=0.6271, Calibration=1.0718, LogLoss=0.6953
# K=137: Accuracy=0.6259, Calibration=1.0718, LogLoss=0.6963
# K=138: Accuracy=0.6251, Calibration=1.0718, LogLoss=0.6972
# K=139: Accuracy=0.6248, Calibration=1.0718, LogLoss=0.6982
# K=140: Accuracy=0.6248, Calibration=1.0718, LogLoss=0.6991
# K=141: Accuracy=0.6251, Calibration=1.0718, LogLoss=0.7001
# K=142: Accuracy=0.6251, Calibration=1.0718, LogLoss=0.7011
# K=143: Accuracy=0.6244, Calibration=1.0717, LogLoss=0.7020
# K=144: Accuracy=0.6248, Calibration=1.0717, LogLoss=0.7030
# K=145: Accuracy=0.6236, Calibration=1.0717, LogLoss=0.7040
# K=146: Accuracy=0.6228, Calibration=1.0717, LogLoss=0.7049
# K=147: Accuracy=0.6221, Calibration=1.0717, LogLoss=0.7059
# K=148: Accuracy=0.6217, Calibration=1.0717, LogLoss=0.7069
# K=149: Accuracy=0.6228, Calibration=1.0717, LogLoss=0.7079
# K=150: Accuracy=0.6221, Calibration=1.0717, LogLoss=0.7089
# K=151: Accuracy=0.6213, Calibration=1.0717, LogLoss=0.7099
# K=152: Accuracy=0.6217, Calibration=1.0717, LogLoss=0.7109
# K=153: Accuracy=0.6213, Calibration=1.0717, LogLoss=0.7119
# K=154: Accuracy=0.6213, Calibration=1.0716, LogLoss=0.7129
# K=155: Accuracy=0.6209, Calibration=1.0716, LogLoss=0.7139
# K=156: Accuracy=0.6201, Calibration=1.0716, LogLoss=0.7149
# K=157: Accuracy=0.6201, Calibration=1.0716, LogLoss=0.7159
# K=158: Accuracy=0.6194, Calibration=1.0716, LogLoss=0.7169
# K=159: Accuracy=0.6190, Calibration=1.0716, LogLoss=0.7179
# K=160: Accuracy=0.6178, Calibration=1.0716, LogLoss=0.7189
# K=161: Accuracy=0.6182, Calibration=1.0716, LogLoss=0.7199
# K=162: Accuracy=0.6174, Calibration=1.0716, LogLoss=0.7210
# K=163: Accuracy=0.6178, Calibration=1.0716, LogLoss=0.7220
# K=164: Accuracy=0.6178, Calibration=1.0716, LogLoss=0.7230
# K=165: Accuracy=0.6174, Calibration=1.0715, LogLoss=0.7241
# K=166: Accuracy=0.6170, Calibration=1.0715, LogLoss=0.7251
# K=167: Accuracy=0.6159, Calibration=1.0715, LogLoss=0.7262
# K=168: Accuracy=0.6155, Calibration=1.0715, LogLoss=0.7272
# K=169: Accuracy=0.6155, Calibration=1.0715, LogLoss=0.7282
# K=170: Accuracy=0.6151, Calibration=1.0715, LogLoss=0.7293
# K=171: Accuracy=0.6155, Calibration=1.0715, LogLoss=0.7303
# K=172: Accuracy=0.6155, Calibration=1.0715, LogLoss=0.7314
# K=173: Accuracy=0.6151, Calibration=1.0715, LogLoss=0.7325
# K=174: Accuracy=0.6155, Calibration=1.0715, LogLoss=0.7335
# K=175: Accuracy=0.6147, Calibration=1.0714, LogLoss=0.7346
# K=176: Accuracy=0.6147, Calibration=1.0714, LogLoss=0.7357
# K=177: Accuracy=0.6147, Calibration=1.0714, LogLoss=0.7367
# K=178: Accuracy=0.6147, Calibration=1.0714, LogLoss=0.7378
# K=179: Accuracy=0.6147, Calibration=1.0714, LogLoss=0.7389
# K=180: Accuracy=0.6155, Calibration=1.0714, LogLoss=0.7400
# K=181: Accuracy=0.6151, Calibration=1.0714, LogLoss=0.7411
# K=182: Accuracy=0.6143, Calibration=1.0714, LogLoss=0.7421
# K=183: Accuracy=0.6140, Calibration=1.0714, LogLoss=0.7432
# K=184: Accuracy=0.6136, Calibration=1.0714, LogLoss=0.7443
# K=185: Accuracy=0.6128, Calibration=1.0713, LogLoss=0.7454
# K=186: Accuracy=0.6124, Calibration=1.0713, LogLoss=0.7465
# K=187: Accuracy=0.6116, Calibration=1.0713, LogLoss=0.7476
# K=188: Accuracy=0.6113, Calibration=1.0713, LogLoss=0.7487
# K=189: Accuracy=0.6116, Calibration=1.0713, LogLoss=0.7499
# K=190: Accuracy=0.6113, Calibration=1.0713, LogLoss=0.7510
# K=191: Accuracy=0.6113, Calibration=1.0713, LogLoss=0.7521
# K=192: Accuracy=0.6113, Calibration=1.0713, LogLoss=0.7532
# K=193: Accuracy=0.6116, Calibration=1.0713, LogLoss=0.7543
# K=194: Accuracy=0.6116, Calibration=1.0713, LogLoss=0.7554
# K=195: Accuracy=0.6113, Calibration=1.0712, LogLoss=0.7566
# K=196: Accuracy=0.6109, Calibration=1.0712, LogLoss=0.7577
# K=197: Accuracy=0.6105, Calibration=1.0712, LogLoss=0.7588
# K=198: Accuracy=0.6097, Calibration=1.0712, LogLoss=0.7600
# K=199: Accuracy=0.6093, Calibration=1.0712, LogLoss=0.7611
# K=200: Accuracy=0.6086, Calibration=1.0712, LogLoss=0.7623
# K=201: Accuracy=0.6086, Calibration=1.0712, LogLoss=0.7634
# K=202: Accuracy=0.6086, Calibration=1.0712, LogLoss=0.7646
# K=203: Accuracy=0.6086, Calibration=1.0712, LogLoss=0.7657
# K=204: Accuracy=0.6082, Calibration=1.0712, LogLoss=0.7669
# K=205: Accuracy=0.6086, Calibration=1.0711, LogLoss=0.7680
# K=206: Accuracy=0.6086, Calibration=1.0711, LogLoss=0.7692
# K=207: Accuracy=0.6093, Calibration=1.0711, LogLoss=0.7703
# K=208: Accuracy=0.6093, Calibration=1.0711, LogLoss=0.7715
# K=209: Accuracy=0.6097, Calibration=1.0711, LogLoss=0.7727
# K=210: Accuracy=0.6093, Calibration=1.0711, LogLoss=0.7739
# K=211: Accuracy=0.6089, Calibration=1.0711, LogLoss=0.7750
# K=212: Accuracy=0.6078, Calibration=1.0711, LogLoss=0.7762
# K=213: Accuracy=0.6074, Calibration=1.0711, LogLoss=0.7774
# K=214: Accuracy=0.6066, Calibration=1.0711, LogLoss=0.7786
# K=215: Accuracy=0.6066, Calibration=1.0710, LogLoss=0.7798
# K=216: Accuracy=0.6074, Calibration=1.0710, LogLoss=0.7810
# K=217: Accuracy=0.6078, Calibration=1.0710, LogLoss=0.7822
# K=218: Accuracy=0.6070, Calibration=1.0710, LogLoss=0.7833
# K=219: Accuracy=0.6062, Calibration=1.0710, LogLoss=0.7845
# K=220: Accuracy=0.6059, Calibration=1.0710, LogLoss=0.7858
# K=221: Accuracy=0.6059, Calibration=1.0710, LogLoss=0.7870
# K=222: Accuracy=0.6059, Calibration=1.0710, LogLoss=0.7882
# K=223: Accuracy=0.6059, Calibration=1.0710, LogLoss=0.7894
# K=224: Accuracy=0.6059, Calibration=1.0709, LogLoss=0.7906
# K=225: Accuracy=0.6059, Calibration=1.0709, LogLoss=0.7918
# K=226: Accuracy=0.6055, Calibration=1.0709, LogLoss=0.7930
# K=227: Accuracy=0.6047, Calibration=1.0709, LogLoss=0.7942
# K=228: Accuracy=0.6043, Calibration=1.0709, LogLoss=0.7955
# K=229: Accuracy=0.6035, Calibration=1.0709, LogLoss=0.7967
# K=230: Accuracy=0.6039, Calibration=1.0709, LogLoss=0.7979
# K=231: Accuracy=0.6039, Calibration=1.0709, LogLoss=0.7992
# K=232: Accuracy=0.6035, Calibration=1.0709, LogLoss=0.8004
# K=233: Accuracy=0.6035, Calibration=1.0709, LogLoss=0.8016
# K=234: Accuracy=0.6039, Calibration=1.0708, LogLoss=0.8029
# K=235: Accuracy=0.6043, Calibration=1.0708, LogLoss=0.8041
# K=236: Accuracy=0.6043, Calibration=1.0708, LogLoss=0.8054
# K=237: Accuracy=0.6043, Calibration=1.0708, LogLoss=0.8066
# K=238: Accuracy=0.6039, Calibration=1.0708, LogLoss=0.8079
# K=239: Accuracy=0.6039, Calibration=1.0708, LogLoss=0.8091
# K=240: Accuracy=0.6039, Calibration=1.0708, LogLoss=0.8104
# K=241: Accuracy=0.6032, Calibration=1.0708, LogLoss=0.8117
# K=242: Accuracy=0.6032, Calibration=1.0708, LogLoss=0.8129
# K=243: Accuracy=0.6035, Calibration=1.0708, LogLoss=0.8142
# K=244: Accuracy=0.6039, Calibration=1.0707, LogLoss=0.8155
# K=245: Accuracy=0.6035, Calibration=1.0707, LogLoss=0.8167
# K=246: Accuracy=0.6024, Calibration=1.0707, LogLoss=0.8180
# K=247: Accuracy=0.6020, Calibration=1.0707, LogLoss=0.8193
# K=248: Accuracy=0.6024, Calibration=1.0707, LogLoss=0.8206
# K=249: Accuracy=0.6024, Calibration=1.0707, LogLoss=0.8219
# K=250: Accuracy=0.6024, Calibration=1.0707, LogLoss=0.8232
# K=251: Accuracy=0.6016, Calibration=1.0707, LogLoss=0.8245
# K=252: Accuracy=0.6016, Calibration=1.0707, LogLoss=0.8257
# K=253: Accuracy=0.6012, Calibration=1.0707, LogLoss=0.8270
# K=254: Accuracy=0.6012, Calibration=1.0706, LogLoss=0.8283
# K=255: Accuracy=0.6008, Calibration=1.0706, LogLoss=0.8296
# K=256: Accuracy=0.6008, Calibration=1.0706, LogLoss=0.8309
# K=257: Accuracy=0.6008, Calibration=1.0706, LogLoss=0.8323
# K=258: Accuracy=0.6001, Calibration=1.0706, LogLoss=0.8336
# K=259: Accuracy=0.5997, Calibration=1.0706, LogLoss=0.8349
# K=260: Accuracy=0.5997, Calibration=1.0706, LogLoss=0.8362
# K=261: Accuracy=0.5997, Calibration=1.0706, LogLoss=0.8375
# K=262: Accuracy=0.5989, Calibration=1.0706, LogLoss=0.8388
# K=263: Accuracy=0.5978, Calibration=1.0706, LogLoss=0.8402
# K=264: Accuracy=0.5974, Calibration=1.0705, LogLoss=0.8415
# K=265: Accuracy=0.5978, Calibration=1.0705, LogLoss=0.8428
# K=266: Accuracy=0.5978, Calibration=1.0705, LogLoss=0.8441
# K=267: Accuracy=0.5974, Calibration=1.0705, LogLoss=0.8455
# K=268: Accuracy=0.5974, Calibration=1.0705, LogLoss=0.8468
# K=269: Accuracy=0.5966, Calibration=1.0705, LogLoss=0.8482
# K=270: Accuracy=0.5966, Calibration=1.0705, LogLoss=0.8495
# K=271: Accuracy=0.5958, Calibration=1.0705, LogLoss=0.8508
# K=272: Accuracy=0.5962, Calibration=1.0705, LogLoss=0.8522
# K=273: Accuracy=0.5962, Calibration=1.0704, LogLoss=0.8535
# K=274: Accuracy=0.5958, Calibration=1.0704, LogLoss=0.8549
# K=275: Accuracy=0.5958, Calibration=1.0704, LogLoss=0.8563
# K=276: Accuracy=0.5958, Calibration=1.0704, LogLoss=0.8576
# K=277: Accuracy=0.5954, Calibration=1.0704, LogLoss=0.8590
# K=278: Accuracy=0.5951, Calibration=1.0704, LogLoss=0.8603
# K=279: Accuracy=0.5954, Calibration=1.0704, LogLoss=0.8617
# K=280: Accuracy=0.5951, Calibration=1.0704, LogLoss=0.8631
# K=281: Accuracy=0.5954, Calibration=1.0704, LogLoss=0.8644
# K=282: Accuracy=0.5954, Calibration=1.0704, LogLoss=0.8658
# K=283: Accuracy=0.5954, Calibration=1.0703, LogLoss=0.8672
# K=284: Accuracy=0.5958, Calibration=1.0703, LogLoss=0.8686
# K=285: Accuracy=0.5958, Calibration=1.0703, LogLoss=0.8700
# K=286: Accuracy=0.5970, Calibration=1.0703, LogLoss=0.8713
# K=287: Accuracy=0.5966, Calibration=1.0703, LogLoss=0.8727
# K=288: Accuracy=0.5962, Calibration=1.0703, LogLoss=0.8741
# K=289: Accuracy=0.5962, Calibration=1.0703, LogLoss=0.8755
# K=290: Accuracy=0.5958, Calibration=1.0703, LogLoss=0.8769
# K=291: Accuracy=0.5958, Calibration=1.0703, LogLoss=0.8783
# K=292: Accuracy=0.5958, Calibration=1.0703, LogLoss=0.8797
# K=293: Accuracy=0.5962, Calibration=1.0702, LogLoss=0.8811
# K=294: Accuracy=0.5962, Calibration=1.0702, LogLoss=0.8825
# K=295: Accuracy=0.5962, Calibration=1.0702, LogLoss=0.8839
# K=296: Accuracy=0.5966, Calibration=1.0702, LogLoss=0.8853
# K=297: Accuracy=0.5966, Calibration=1.0702, LogLoss=0.8868
# K=298: Accuracy=0.5962, Calibration=1.0702, LogLoss=0.8882
# K=299: Accuracy=0.5962, Calibration=1.0702, LogLoss=0.8896
# K=300: Accuracy=0.5958, Calibration=1.0702, LogLoss=0.8910
# K=301: Accuracy=0.5962, Calibration=1.0702, LogLoss=0.8924
# K=302: Accuracy=0.5958, Calibration=1.0701, LogLoss=0.8939
# K=303: Accuracy=0.5958, Calibration=1.0701, LogLoss=0.8953
# K=304: Accuracy=0.5954, Calibration=1.0701, LogLoss=0.8967
# K=305: Accuracy=0.5954, Calibration=1.0701, LogLoss=0.8982
# K=306: Accuracy=0.5954, Calibration=1.0701, LogLoss=0.8996
# K=307: Accuracy=0.5951, Calibration=1.0701, LogLoss=0.9010
# K=308: Accuracy=0.5954, Calibration=1.0701, LogLoss=0.9025
# K=309: Accuracy=0.5954, Calibration=1.0701, LogLoss=0.9039
# K=310: Accuracy=0.5954, Calibration=1.0701, LogLoss=0.9054
# K=311: Accuracy=0.5954, Calibration=1.0701, LogLoss=0.9068
# K=312: Accuracy=0.5958, Calibration=1.0700, LogLoss=0.9083
# K=313: Accuracy=0.5962, Calibration=1.0700, LogLoss=0.9097
# K=314: Accuracy=0.5954, Calibration=1.0700, LogLoss=0.9112
# K=315: Accuracy=0.5951, Calibration=1.0700, LogLoss=0.9126
# K=316: Accuracy=0.5951, Calibration=1.0700, LogLoss=0.9141
# K=317: Accuracy=0.5951, Calibration=1.0700, LogLoss=0.9156
# K=318: Accuracy=0.5954, Calibration=1.0700, LogLoss=0.9170
# K=319: Accuracy=0.5951, Calibration=1.0700, LogLoss=0.9185
# K=320: Accuracy=0.5939, Calibration=1.0700, LogLoss=0.9200
# K=321: Accuracy=0.5943, Calibration=1.0700, LogLoss=0.9214
# K=322: Accuracy=0.5943, Calibration=1.0699, LogLoss=0.9229
# K=323: Accuracy=0.5951, Calibration=1.0699, LogLoss=0.9244
# K=324: Accuracy=0.5947, Calibration=1.0699, LogLoss=0.9259
# K=325: Accuracy=0.5943, Calibration=1.0699, LogLoss=0.9274
# K=326: Accuracy=0.5943, Calibration=1.0699, LogLoss=0.9289
# K=327: Accuracy=0.5939, Calibration=1.0699, LogLoss=0.9303
# K=328: Accuracy=0.5943, Calibration=1.0699, LogLoss=0.9318
# K=329: Accuracy=0.5943, Calibration=1.0699, LogLoss=0.9333
# K=330: Accuracy=0.5943, Calibration=1.0699, LogLoss=0.9348
# K=331: Accuracy=0.5939, Calibration=1.0699, LogLoss=0.9363
# K=332: Accuracy=0.5939, Calibration=1.0698, LogLoss=0.9378
# K=333: Accuracy=0.5943, Calibration=1.0698, LogLoss=0.9393
# K=334: Accuracy=0.5943, Calibration=1.0698, LogLoss=0.9408
# K=335: Accuracy=0.5943, Calibration=1.0698, LogLoss=0.9423
# K=336: Accuracy=0.5943, Calibration=1.0698, LogLoss=0.9439
# K=337: Accuracy=0.5943, Calibration=1.0698, LogLoss=0.9454
# K=338: Accuracy=0.5947, Calibration=1.0698, LogLoss=0.9469
# K=339: Accuracy=0.5947, Calibration=1.0698, LogLoss=0.9484
# K=340: Accuracy=0.5943, Calibration=1.0698, LogLoss=0.9499
# K=341: Accuracy=0.5943, Calibration=1.0697, LogLoss=0.9514
# K=342: Accuracy=0.5943, Calibration=1.0697, LogLoss=0.9530
# K=343: Accuracy=0.5943, Calibration=1.0697, LogLoss=0.9545
# K=344: Accuracy=0.5943, Calibration=1.0697, LogLoss=0.9560
# K=345: Accuracy=0.5943, Calibration=1.0697, LogLoss=0.9576
# K=346: Accuracy=0.5943, Calibration=1.0697, LogLoss=0.9591
# K=347: Accuracy=0.5943, Calibration=1.0697, LogLoss=0.9606
# K=348: Accuracy=0.5947, Calibration=1.0697, LogLoss=0.9622
# K=349: Accuracy=0.5947, Calibration=1.0697, LogLoss=0.9637
# K=350: Accuracy=0.5947, Calibration=1.0697, LogLoss=0.9653
# K=351: Accuracy=0.5951, Calibration=1.0696, LogLoss=0.9668
# K=352: Accuracy=0.5951, Calibration=1.0696, LogLoss=0.9684
# K=353: Accuracy=0.5958, Calibration=1.0696, LogLoss=0.9699
# K=354: Accuracy=0.5954, Calibration=1.0696, LogLoss=0.9715
# K=355: Accuracy=0.5954, Calibration=1.0696, LogLoss=0.9730
# K=356: Accuracy=0.5947, Calibration=1.0696, LogLoss=0.9746
# K=357: Accuracy=0.5947, Calibration=1.0696, LogLoss=0.9761
# K=358: Accuracy=0.5947, Calibration=1.0696, LogLoss=0.9777
# K=359: Accuracy=0.5943, Calibration=1.0696, LogLoss=0.9793
# K=360: Accuracy=0.5943, Calibration=1.0696, LogLoss=0.9808
# K=361: Accuracy=0.5939, Calibration=1.0696, LogLoss=0.9824
# K=362: Accuracy=0.5935, Calibration=1.0695, LogLoss=0.9840
# K=363: Accuracy=0.5935, Calibration=1.0695, LogLoss=0.9856
# K=364: Accuracy=0.5931, Calibration=1.0695, LogLoss=0.9871
# K=365: Accuracy=0.5927, Calibration=1.0695, LogLoss=0.9887
# K=366: Accuracy=0.5927, Calibration=1.0695, LogLoss=0.9903
# K=367: Accuracy=0.5927, Calibration=1.0695, LogLoss=0.9919
# K=368: Accuracy=0.5927, Calibration=1.0695, LogLoss=0.9935
# K=369: Accuracy=0.5927, Calibration=1.0695, LogLoss=0.9951
# K=370: Accuracy=0.5927, Calibration=1.0695, LogLoss=0.9966
# K=371: Accuracy=0.5931, Calibration=1.0695, LogLoss=0.9982
# K=372: Accuracy=0.5931, Calibration=1.0694, LogLoss=0.9998
# K=373: Accuracy=0.5931, Calibration=1.0694, LogLoss=1.0014
# K=374: Accuracy=0.5931, Calibration=1.0694, LogLoss=1.0030
# K=375: Accuracy=0.5931, Calibration=1.0694, LogLoss=1.0046
# K=376: Accuracy=0.5931, Calibration=1.0694, LogLoss=1.0062
# K=377: Accuracy=0.5931, Calibration=1.0694, LogLoss=1.0078
# K=378: Accuracy=0.5927, Calibration=1.0694, LogLoss=1.0095
# K=379: Accuracy=0.5924, Calibration=1.0694, LogLoss=1.0111
# K=380: Accuracy=0.5920, Calibration=1.0694, LogLoss=1.0127
# K=381: Accuracy=0.5920, Calibration=1.0694, LogLoss=1.0143
# K=382: Accuracy=0.5920, Calibration=1.0694, LogLoss=1.0159
# K=383: Accuracy=0.5920, Calibration=1.0693, LogLoss=1.0175
# K=384: Accuracy=0.5920, Calibration=1.0693, LogLoss=1.0192
# K=385: Accuracy=0.5920, Calibration=1.0693, LogLoss=1.0208
# K=386: Accuracy=0.5920, Calibration=1.0693, LogLoss=1.0224
# K=387: Accuracy=0.5920, Calibration=1.0693, LogLoss=1.0240
# K=388: Accuracy=0.5924, Calibration=1.0693, LogLoss=1.0257
# K=389: Accuracy=0.5924, Calibration=1.0693, LogLoss=1.0273
# K=390: Accuracy=0.5924, Calibration=1.0693, LogLoss=1.0289
# K=391: Accuracy=0.5924, Calibration=1.0693, LogLoss=1.0306
# K=392: Accuracy=0.5924, Calibration=1.0693, LogLoss=1.0322
# K=393: Accuracy=0.5924, Calibration=1.0693, LogLoss=1.0339
# K=394: Accuracy=0.5924, Calibration=1.0693, LogLoss=1.0355
# K=395: Accuracy=0.5924, Calibration=1.0692, LogLoss=1.0372
# K=396: Accuracy=0.5920, Calibration=1.0692, LogLoss=1.0388
# K=397: Accuracy=0.5920, Calibration=1.0692, LogLoss=1.0405
# K=398: Accuracy=0.5920, Calibration=1.0692, LogLoss=1.0421
# K=399: Accuracy=0.5916, Calibration=1.0692, LogLoss=1.0438
# K=400: Accuracy=0.5920, Calibration=1.0692, LogLoss=1.0454
# K=401: Accuracy=0.5916, Calibration=1.0692, LogLoss=1.0471
# K=402: Accuracy=0.5916, Calibration=1.0692, LogLoss=1.0488
# K=403: Accuracy=0.5920, Calibration=1.0692, LogLoss=1.0504
# K=404: Accuracy=0.5927, Calibration=1.0692, LogLoss=1.0521
# K=405: Accuracy=0.5927, Calibration=1.0692, LogLoss=1.0538
# K=406: Accuracy=0.5931, Calibration=1.0692, LogLoss=1.0554
# K=407: Accuracy=0.5931, Calibration=1.0691, LogLoss=1.0571
# K=408: Accuracy=0.5943, Calibration=1.0691, LogLoss=1.0588
# K=409: Accuracy=0.5943, Calibration=1.0691, LogLoss=1.0605
# K=410: Accuracy=0.5939, Calibration=1.0691, LogLoss=1.0621
# K=411: Accuracy=0.5939, Calibration=1.0691, LogLoss=1.0638
# K=412: Accuracy=0.5939, Calibration=1.0691, LogLoss=1.0655
# K=413: Accuracy=0.5943, Calibration=1.0691, LogLoss=1.0672
# K=414: Accuracy=0.5943, Calibration=1.0691, LogLoss=1.0689
# K=415: Accuracy=0.5939, Calibration=1.0691, LogLoss=1.0706
# K=416: Accuracy=0.5943, Calibration=1.0691, LogLoss=1.0723
# K=417: Accuracy=0.5939, Calibration=1.0691, LogLoss=1.0740
# K=418: Accuracy=0.5939, Calibration=1.0691, LogLoss=1.0757
# K=419: Accuracy=0.5935, Calibration=1.0690, LogLoss=1.0774
# K=420: Accuracy=0.5939, Calibration=1.0690, LogLoss=1.0791
# K=421: Accuracy=0.5935, Calibration=1.0690, LogLoss=1.0808
# K=422: Accuracy=0.5931, Calibration=1.0690, LogLoss=1.0825
# K=423: Accuracy=0.5924, Calibration=1.0690, LogLoss=1.0842
# K=424: Accuracy=0.5920, Calibration=1.0690, LogLoss=1.0859
# K=425: Accuracy=0.5924, Calibration=1.0690, LogLoss=1.0876
# K=426: Accuracy=0.5924, Calibration=1.0690, LogLoss=1.0893
# K=427: Accuracy=0.5927, Calibration=1.0690, LogLoss=1.0910
# K=428: Accuracy=0.5927, Calibration=1.0690, LogLoss=1.0927
# K=429: Accuracy=0.5927, Calibration=1.0690, LogLoss=1.0945
# K=430: Accuracy=0.5927, Calibration=1.0690, LogLoss=1.0962
# K=431: Accuracy=0.5927, Calibration=1.0690, LogLoss=1.0979
# K=432: Accuracy=0.5924, Calibration=1.0689, LogLoss=1.0996
# K=433: Accuracy=0.5920, Calibration=1.0689, LogLoss=1.1014
# K=434: Accuracy=0.5920, Calibration=1.0689, LogLoss=1.1031
# K=435: Accuracy=0.5920, Calibration=1.0689, LogLoss=1.1048
# K=436: Accuracy=0.5920, Calibration=1.0689, LogLoss=1.1066
# K=437: Accuracy=0.5920, Calibration=1.0689, LogLoss=1.1083
# K=438: Accuracy=0.5916, Calibration=1.0689, LogLoss=1.1100
# K=439: Accuracy=0.5912, Calibration=1.0689, LogLoss=1.1118
# K=440: Accuracy=0.5908, Calibration=1.0689, LogLoss=1.1135
# K=441: Accuracy=0.5908, Calibration=1.0689, LogLoss=1.1153
# K=442: Accuracy=0.5912, Calibration=1.0689, LogLoss=1.1170
# K=443: Accuracy=0.5916, Calibration=1.0689, LogLoss=1.1188
# K=444: Accuracy=0.5916, Calibration=1.0689, LogLoss=1.1205
# K=445: Accuracy=0.5916, Calibration=1.0689, LogLoss=1.1223
# K=446: Accuracy=0.5916, Calibration=1.0689, LogLoss=1.1240
# K=447: Accuracy=0.5916, Calibration=1.0688, LogLoss=1.1258
# K=448: Accuracy=0.5916, Calibration=1.0688, LogLoss=1.1275
# K=449: Accuracy=0.5912, Calibration=1.0688, LogLoss=1.1293
# K=450: Accuracy=0.5908, Calibration=1.0688, LogLoss=1.1311
# K=451: Accuracy=0.5908, Calibration=1.0688, LogLoss=1.1328
# K=452: Accuracy=0.5908, Calibration=1.0688, LogLoss=1.1346
# K=453: Accuracy=0.5912, Calibration=1.0688, LogLoss=1.1364
# K=454: Accuracy=0.5908, Calibration=1.0688, LogLoss=1.1381
# K=455: Accuracy=0.5908, Calibration=1.0688, LogLoss=1.1399
# K=456: Accuracy=0.5904, Calibration=1.0688, LogLoss=1.1417
# K=457: Accuracy=0.5904, Calibration=1.0688, LogLoss=1.1435
# K=458: Accuracy=0.5904, Calibration=1.0688, LogLoss=1.1452
# K=459: Accuracy=0.5904, Calibration=1.0688, LogLoss=1.1470
# K=460: Accuracy=0.5901, Calibration=1.0688, LogLoss=1.1488
# K=461: Accuracy=0.5901, Calibration=1.0688, LogLoss=1.1506
# K=462: Accuracy=0.5897, Calibration=1.0687, LogLoss=1.1524
# K=463: Accuracy=0.5901, Calibration=1.0687, LogLoss=1.1542
# K=464: Accuracy=0.5897, Calibration=1.0687, LogLoss=1.1560
# K=465: Accuracy=0.5904, Calibration=1.0687, LogLoss=1.1578
# K=466: Accuracy=0.5904, Calibration=1.0687, LogLoss=1.1595
# K=467: Accuracy=0.5904, Calibration=1.0687, LogLoss=1.1613
# K=468: Accuracy=0.5904, Calibration=1.0687, LogLoss=1.1631
# K=469: Accuracy=0.5908, Calibration=1.0687, LogLoss=1.1649
# K=470: Accuracy=0.5908, Calibration=1.0687, LogLoss=1.1667
# K=471: Accuracy=0.5908, Calibration=1.0687, LogLoss=1.1685
# K=472: Accuracy=0.5908, Calibration=1.0687, LogLoss=1.1704
# K=473: Accuracy=0.5908, Calibration=1.0687, LogLoss=1.1722
# K=474: Accuracy=0.5908, Calibration=1.0687, LogLoss=1.1740
# K=475: Accuracy=0.5908, Calibration=1.0687, LogLoss=1.1758
# K=476: Accuracy=0.5912, Calibration=1.0687, LogLoss=1.1776
# K=477: Accuracy=0.5912, Calibration=1.0687, LogLoss=1.1794
# K=478: Accuracy=0.5912, Calibration=1.0687, LogLoss=1.1812
# K=479: Accuracy=0.5912, Calibration=1.0686, LogLoss=1.1831
# K=480: Accuracy=0.5916, Calibration=1.0686, LogLoss=1.1849
# K=481: Accuracy=0.5912, Calibration=1.0686, LogLoss=1.1867
# K=482: Accuracy=0.5912, Calibration=1.0686, LogLoss=1.1885
# K=483: Accuracy=0.5912, Calibration=1.0686, LogLoss=1.1904
# K=484: Accuracy=0.5912, Calibration=1.0686, LogLoss=1.1922
# K=485: Accuracy=0.5912, Calibration=1.0686, LogLoss=1.1940
# K=486: Accuracy=0.5908, Calibration=1.0686, LogLoss=1.1958
# K=487: Accuracy=0.5908, Calibration=1.0686, LogLoss=1.1977
# K=488: Accuracy=0.5908, Calibration=1.0686, LogLoss=1.1995
# K=489: Accuracy=0.5908, Calibration=1.0686, LogLoss=1.2014
# K=490: Accuracy=0.5908, Calibration=1.0686, LogLoss=1.2032
# K=491: Accuracy=0.5904, Calibration=1.0686, LogLoss=1.2050
# K=492: Accuracy=0.5904, Calibration=1.0686, LogLoss=1.2069
# K=493: Accuracy=0.5904, Calibration=1.0686, LogLoss=1.2087
# K=494: Accuracy=0.5904, Calibration=1.0686, LogLoss=1.2106
# K=495: Accuracy=0.5904, Calibration=1.0686, LogLoss=1.2124
# K=496: Accuracy=0.5901, Calibration=1.0685, LogLoss=1.2143
# K=497: Accuracy=0.5901, Calibration=1.0685, LogLoss=1.2161
# K=498: Accuracy=0.5904, Calibration=1.0685, LogLoss=1.2180
# K=499: Accuracy=0.5901, Calibration=1.0685, LogLoss=1.2198
